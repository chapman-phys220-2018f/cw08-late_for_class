# %%
import numpy as np
import sinesum as ss
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # CW 08--Fourier Series
#
# ##### Abby Wheaton and Frank Entriken

# %% [markdown]
# ### The following six plots have alpha=0.01 and n = 1,3,5,10,30,100

# %%
k=0
n=0
x=[]
y=[]
for i in range(1):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.01*2*np.pi, n))
plt.plot(x,y, marker = 'o')

# %%
k=0
n=0
x=[]
y=[]
for i in range(3):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.01*2*np.pi, n))
plt.plot(x,y)

# %%
k=0
n=0
x=[]
y=[]
for i in range(5):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.01*2*np.pi, n))
plt.plot(x,y)

# %%
k=0
n=0
x=[]
y=[]
for i in range(10):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.01*2*np.pi, n))
plt.plot(x,y)

# %%
k=0
n=0
x=[]
y=[]
for i in range(30):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.01*2*np.pi, n))
plt.plot(x,y)

# %%
k=0
n=0
x=[]
y=[]
for i in range(100):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.01*2*np.pi, n))
plt.plot(x,y)

# %% [markdown]
# ## Analysis
#
# As the length of the Fourier Series Expansion increases, the approximation quality increases. The Fourier Series Expansion converges to 1 because 0 < t < T/2

# %% [markdown]
# ### The following six plots have alpha=0.25 and n = 1,3,5,10,30,100

# %%
k=0
n=0
x=[]
y=[]
for i in range(1):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.25*2*np.pi, n))
plt.plot(x,y, marker = 'o')

# %%
k=0
n=0
x=[]
y=[]
for i in range(3):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.25*2*np.pi, n))
plt.plot(x,y)

# %%
k=0
n=0
x=[]
y=[]
for i in range(5):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.25*2*np.pi, n))
plt.plot(x,y)

# %%
k=0
n=0
x=[]
y=[]
for i in range(10):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.25*2*np.pi, n))
plt.plot(x,y)

# %%
k=0
n=0
x=[]
y=[]
for i in range(30):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.25*2*np.pi, n))
plt.plot(x,y)

# %%
k=0
n=0
x=[]
y=[]
for i in range(100):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.25*2*np.pi, n))
plt.plot(x,y)

# %% [markdown]
# ## Analysis
#
# As the length of the Fourier Series Expansion increases, the approximation quality increases. The Fourier Series Expansion converges to 1 because 0 < t < T/2

# %% [markdown]
# ### The following six plots have alpha=0.49 and n = 1,3,5,10,30,100

# %%
k=0
n=0
x=[]
y=[]
for i in range(1):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.49*2*np.pi, n))
plt.plot(x,y, marker = 'o')

# %%
k=0
n=0
x=[]
y=[]
for i in range(3):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.49*2*np.pi, n))
plt.plot(x,y)

# %%
k=0
n=0
x=[]
y=[]
for i in range(5):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.49*2*np.pi, n))
plt.plot(x,y)

# %%
k=0
n=0
x=[]
y=[]
for i in range(10):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.49*2*np.pi, n))
plt.plot(x,y)

# %%
k=0
n=0
x=[]
y=[]
for i in range(30):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.49*2*np.pi, n))
plt.plot(x,y)

# %%
k=0
n=0
x=[]
y=[]
for i in range(100):
    k+=1
    x.append(k)
    n+=1
    y.append(ss.s(0.49*2*np.pi, n))
plt.plot(x,y)

# %% [markdown]
# ## Analysis
#
# As the length of the Fourier Series Expansion increases, the approximation quality increases. The Fourier Series Expansion converges to 1 because 0 < t < T/2

# %% [markdown]
# # Conclusions
#
# Because alpha > 0 for each one of these Fourier Series expansions, they all converge to 1. If alpha were <= 0, then the convergence of each Fourier Series expansion would be different. Also, as n gets larger, the Fourier Series Expansion of the function gets more accurate. I would predict that as n approaches infinity, the Fourier Series Expansion would converge to the correct value as specified in f(t), the piecewise function.
